# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sb

# %%
data = pd.read_csv('./files/IBM_HR_ATTRITION.csv', ',')

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
sb.catplot(x = "Attrition", y = "JobSatisfaction", data = data)

# %%
sb.catplot(x = "Attrition", y = "JobSatisfaction", data = data, kind = "box")

# %%
sb.boxplot(x = "Attrition", y = "JobSatisfaction", data = data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='JobSatisfaction'>

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
sb.boxplot(x = "Attrition", y = "TotalWorkingYears", data = data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='TotalWorkingYears'>

# %%
data_iso = data[data['TotalWorkingYears'] < 20]; data_iso['TotalWorkingYears'].describe()
# Out:
# count    1233.000000
# mean        8.529603
# std         4.527080
# min         0.000000
# 25%         5.000000
# 50%         8.000000
# 75%        11.000000
# max        19.000000
# Name: TotalWorkingYears, dtype: float64

# %%
sb.boxplot(x = "Attrition", y = "TotalWorkingYears", data = data_iso)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='TotalWorkingYears'>

# %%
data['TotalWorkingYears'].describe()
# Out:
# count    1470.000000
# mean       11.279592
# std         7.780782
# min         0.000000
# 25%         6.000000
# 50%        10.000000
# 75%        15.000000
# max        40.000000
# Name: TotalWorkingYears, dtype: float64

# %%
data_iso['Attrition'] = data_iso['Attrition'].map({'Yes':1, 'No':0}); data_iso['Attrition']
# Out:
# <ipython-input-43-ed8f0fc60a8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_iso['Attrition'] = data_iso['Attrition'].map({'Yes':1, 'No':0}); data_iso['Attrition']
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1465   NaN
# 1466   NaN
# 1467   NaN
# 1468   NaN
# 1469   NaN
# Name: Attrition, Length: 1233, dtype: float64

# %%
sb.catplot(x="EducationField", y="Attrition", data=data_iso, kind="bar", height=8)

# %%
sb.displot(data['MonthlyIncome'], kde=True)

# %%
sb.kdeplot(data[data['MonthlyIncome'] < 5000]['MonthlyIncome'])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Density'>

# %%
sb.lmplot(x="DistanceFromHome", y="Attrition", data = data)

# %%
sb.lmplot(x="YearsWithCurrManager", y="Attrition", data = data)
