# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sb

# %%
data = pd.read_csv('./files/sales_predictions.csv', ',')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
data_sample = data.sample(50)

# %%
sb.relplot(data=data_sample, x='date', y='item_price', aspect=3)

# %%
sb.relplot(data=data_sample, x = "date", y = "item_price", aspect = 3, kind="line")

# %%
data_sample['date'] = pd.to_datetime(data_sample['date']); data_sample['date']
# Out:
# 1685732   2014-05-17
# 1261411   2013-02-12
# 121583    2013-08-02
# 1442403   2014-01-02
# 2747295   2015-07-24
# 2067009   2014-10-14
# 1845206   2014-07-13
# 17426     2013-05-01
# 1149595   2013-12-24
# 237951    2013-03-15
# 927677    2013-09-29
# 1963576   2014-05-09
# 2163072   2014-07-11
# 1863030   2014-05-07
# 2926149   2015-10-30
# 1802210   2014-05-07
# 2247256   2014-12-27
# 603401    2013-01-06
# 730216    2013-07-17
# 2318830   2014-12-13
# 1698331   2014-05-31
# 2743482   2015-07-21
# 992341    2013-03-10
# 2701075   2015-05-06
# 2737710   2015-07-26
# 831195    2013-05-08
# 151226    2013-02-18
# 1030810   2013-11-28
# 924226    2013-11-09
# 2232379   2014-12-28
# 1997108   2014-09-22
# 539932    2013-06-30
# 2498291   2015-01-03
# 1899665   2014-08-27
# 1080266   2013-07-11
# 2823438   2015-08-18
# 2322627   2014-12-28
# 632111    2013-06-07
# 1229139   2013-12-27
# 2853717   2015-09-30
# 1434559   2014-04-02
# 531003    2013-05-19
# 994289    2013-07-10
# ...

# %%
sb.relplot(data=data_sample, x='date', y='item_price', aspect=3)

# %%
sb.relplot(data=data_sample, x="date", y="item_price", aspect=3, kind='line')
