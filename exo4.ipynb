# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
ibm = pd.read_csv('./files/IBM_HR_ATTRITION.csv', ',')

# %%
ibm['Attrition'] = ibm['Attrition'].replace({'Yes':1, 'No':0}) ;ibm['Attrition']
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64

# %%
sb.lmplot(x = 'DistanceFromHome', y = "Attrition", data = ibm)

# %%
q1y = ibm[ibm['Attrition'] == 1]['TotalWorkingYears'].quantile(.25)
q3y = ibm[ibm['Attrition'] == 1]['TotalWorkingYears'].quantile(.75)
q1n = ibm[ibm['Attrition'] == 0]['TotalWorkingYears'].quantile(.25)
q3n = ibm[ibm['Attrition'] == 0]['TotalWorkingYears'].quantile(.75)

# %%
q3y+(1.5*(q3y-q1y))
# Out:
# 20.5

# %%
sb.catplot(x="EducationField", y="Attrition", data=ibm[ibm['TotalWorkingYears'] < q3y+(1.5*(q3y-q1y))], kind="bar", height=8)
