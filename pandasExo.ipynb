# %% [markdown]
# Visualisation d’un nuage de points et exploration des
# variables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

pd.set_option('display.max_columns', 100)

# %%
house = pd.read_csv('./files/house_pricing.csv', ','); house
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
sb.relplot(x="SalePrice", y="LotArea",  hue="SalePrice", data=house)

# %%
house_500 = house[house['SalePrice'] < 500000]
house_2 = house_500[house_500['LotArea'] < 20000]
sb.relplot(x="SalePrice", y="LotArea",  hue="SalePrice", data=house_2)

# %%
sb.relplot(x="LotFrontage", y="LotArea", hue="LotFrontage", data = house)

# %%
house_200 = house[house['LotFrontage'] < 200]
house_2 = house_200[house_200['LotArea'] < 100000]
sb.relplot(x="LotFrontage", y="LotArea", hue="LotFrontage", data = house_2)

# %% [markdown]
# Visualisation de relations continues

# %%
sales = pd.read_csv('./files/sales_predictions.csv')

# %%
sales_50 = sales.sample(n=50); sales_50
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2127671  04.11.2014              22       54     4678      299.00
# 2680860  13.06.2015              29       46     8280      199.33
# 1244724  11.12.2013              11       31     5660     1299.00
# 2643443  20.05.2015              28       27    17406      149.00
# 2460143  21.02.2015              25        4    19797      699.00
# 441546   29.05.2013               4       28     5324      299.00
# 1742567  07.06.2014              17       15     7834      799.00
# 2522873  29.03.2015              26       16     4717      299.00
# 826683   21.08.2013               7        2    10002      398.90
# 1288972  04.01.2014              12       57     3629      599.00
# 128738   27.02.2013               1       42    16581      399.00
# 322669   09.03.2013               2       24     6156       99.00
# 2460597  12.02.2015              25        4     3341     2599.00
# ...

# %%
sb.relplot(x="date", y="item_price", data = sales_50)

# %%
sales_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 767213 to 1601395
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            50 non-null     object
#  1   date_block_num  50 non-null     int64
#  2   shop_id         50 non-null     int64
#  3   item_id         50 non-null     int64
#  4   item_price      50 non-null     float64
#  5   item_cnt_day    50 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 2.7+ KB

# %%
sales_50['date'] = pd.to_datetime(sales_50['date'], format= '%d.%m.%Y'); sales_50
# Out:
#               date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 2127671 2014-11-04              22       54     4678      299.00           1.0
# 2680860 2015-06-13              29       46     8280      199.33           1.0
# 1244724 2013-12-11              11       31     5660     1299.00           2.0
# 2643443 2015-05-20              28       27    17406      149.00           1.0
# 2460143 2015-02-21              25        4    19797      699.00           1.0
# 441546  2013-05-29               4       28     5324      299.00           1.0
# 1742567 2014-06-07              17       15     7834      799.00           1.0
# 2522873 2015-03-29              26       16     4717      299.00           1.0
# 826683  2013-08-21               7        2    10002      398.90           1.0
# 1288972 2014-01-04              12       57     3629      599.00           1.0
# 128738  2013-02-27               1       42    16581      399.00           1.0
# ...

# %%
sales_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 767213 to 1601395
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            50 non-null     datetime64[ns]
#  1   date_block_num  50 non-null     int64
#  2   shop_id         50 non-null     int64
#  3   item_id         50 non-null     int64
#  4   item_price      50 non-null     float64
#  5   item_cnt_day    50 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(3)
# memory usage: 2.7 KB

# %%
g = sb.relplot(x="date", y="item_price", data = sales_50, height=8, aspect=3, kind="line")
# g.fig.set_figwidth(14)
# g.fig.set_figheight(7)

# %% [markdown]
# Visualisation de variables catégoriques

# %%
ibm = pd.read_csv('./files/IBM_HR_ATTRITION.csv', ','); 
pd.set_option('display.max_rows', 100)
ibm
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
ibm.describe(include="all")
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %%
sb.catplot(y="JobSatisfaction", x="Attrition", data=ibm, kind="box")

# %%
sb.catplot(x="JobSatisfaction", data = ibm[ibm['Attrition'] == "Yes"], kind="count")

# %%
sb.boxplot(x=ibm[ibm['Attrition'] == "Yes"]['JobSatisfaction'])
# Out:
# <AxesSubplot:xlabel='JobSatisfaction'>

# %%
sb.catplot(y="TotalWorkingYears", x="Attrition", data=ibm, kind="box")

# %%
ibm[ibm['Attrition'] == "Yes"]['TotalWorkingYears'].describe()
# Out:
# count    237.000000
# mean       8.244726
# std        7.169204
# min        0.000000
# 25%        3.000000
# 50%        7.000000
# 75%       10.000000
# max       40.000000
# Name: TotalWorkingYears, dtype: float64

# %%
q1y = ibm[ibm['Attrition'] == "Yes"]['TotalWorkingYears'].quantile(.25)
q3y = ibm[ibm['Attrition'] == "Yes"]['TotalWorkingYears'].quantile(.75)
q1n = ibm[ibm['Attrition'] == "No"]['TotalWorkingYears'].quantile(.25)
q3n = ibm[ibm['Attrition'] == "No"]['TotalWorkingYears'].quantile(.75)

# %%
ibm_yes = ibm[(ibm['TotalWorkingYears'] > q3y+(1.5*(q3y-q1y))) & (ibm['Attrition'] == "Yes")]; ibm_yes
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 45     41       Yes      Travel_Rarely       1360  Research & Development
# 50     48       Yes      Travel_Rarely        626  Research & Development
# 126    58       Yes      Travel_Rarely        147  Research & Development
# 568    55       Yes      Travel_Rarely        725  Research & Development
# 595    58       Yes      Travel_Rarely        286  Research & Development
# 706    40       Yes         Non-Travel       1479                   Sales
# 749    52       Yes      Travel_Rarely        266                   Sales
# 789    44       Yes      Travel_Rarely       1376         Human Resources
# 813    39       Yes  Travel_Frequently        203  Research & Development
# 838    42       Yes  Travel_Frequently        481                   Sales
# 913    45       Yes      Travel_Rarely       1449                   Sales
# 966    58       Yes      Travel_Rarely        601  Research & Development
# ...

# %%
ibm_no = ibm[(ibm['TotalWorkingYears'] > q3n+(1.5*(q3n-q1n))) & (ibm['Attrition'] == "No")]; ibm_no
# Out:
# nt
# 1086   50        No  Travel_Frequently        333  Research & Development
# 1116   55        No      Travel_Rarely        685                   Sales
# 1138   50        No  Travel_Frequently       1234  Research & Development
# 1184   54        No      Travel_Rarely        584  Research & Development
# 1264   55        No      Travel_Rarely        478  Research & Development
# 1301   58        No         Non-Travel        350                   Sales
# 1401   55        No      Travel_Rarely        189         Human Resources
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 85                   7          3    Life Sciences              1
# 98                  10          4          Medical              1
# 187                 14          4          Medical              1
# 190                  1          4    Life Sciences              1
# 233                  1          4          Medical              1
# ...

# %%
ibm_iso = ibm[(ibm['TotalWorkingYears'] < q3y+(1.5*(q3y-q1y)))]

# %%
sb.catplot(y="TotalWorkingYears", x="Attrition", data=ibm_iso, kind="box")

# %%
ibm_yes.describe()
# Out:
#              Age    DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count  16.000000    16.000000         16.000000  16.000000           16.0
# mean   48.812500   708.937500          7.687500   3.125000            1.0
# std     6.774646   482.389119          7.542933   0.957427            0.0
# min    39.000000   147.000000          1.000000   1.000000            1.0
# 25%    43.500000   281.250000          2.000000   3.000000            1.0
# 50%    47.500000   604.000000          4.500000   3.000000            1.0
# 75%    55.000000  1159.750000         12.000000   4.000000            1.0
# max    58.000000  1479.000000         24.000000   5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count       16.000000                16.000000   16.000000       16.000000
# mean      1004.312500                 2.250000   73.125000        2.500000
# std        515.431563                 1.183216   21.960191        0.966092
# ...

# %%
ibm2 = ibm[(ibm['Attrition'] == "Yes") & (ibm['JobSatisfaction'] == 4)]; ibm2
# Out:
# Sales Executive                4
# 1036               3         1      Laboratory Technician                4
# 1111               2         3     Manufacturing Director                4
# 1153               3         1       Sales Representative                4
# 1167               1         2            Sales Executive                4
# 1186               3         2            Sales Executive                4
# 1213               3         1       Sales Representative                4
# 1246               2         1            Human Resources                4
# 1281               3         2            Sales Executive                4
# 1332               2         1         Research Scientist                4
# 1338               3         1       Sales Representative                4
# 1354               3         1      Laboratory Technician                4
# 1390               2         1      Laboratory Technician                4
# ...

# %%
ibm.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
ibm2.describe()
# Out:
#              Age    DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count  52.000000    52.000000         52.000000  52.000000           52.0
# mean   33.961538   748.980769         10.000000   2.711538            1.0
# std    10.900551   357.841322          8.565778   1.108550            0.0
# min    18.000000   121.000000          1.000000   1.000000            1.0
# 25%    27.500000   469.250000          2.000000   2.000000            1.0
# 50%    31.000000   728.500000          8.000000   3.000000            1.0
# 75%    39.500000  1055.000000         15.500000   3.250000            1.0
# max    58.000000  1485.000000         27.000000   5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count       52.000000                52.000000   52.000000       52.000000
# mean       985.673077                 2.538462   63.519231        2.403846
# std        619.045968                 1.128274   19.454815        0.798519
# ...

# %%
ibm['Attrition'] = ibm['Attrition'].map({"Yes":0,"No":1}); ibm
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          0      Travel_Rarely       1102                   Sales
# 1      49          1  Travel_Frequently        279  Research & Development
# 2      37          0      Travel_Rarely       1373  Research & Development
# 3      33          1  Travel_Frequently       1392  Research & Development
# 4      27          1      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          1  Travel_Frequently        884  Research & Development
# 1466   39          1      Travel_Rarely        613  Research & Development
# 1467   27          1      Travel_Rarely        155  Research & Development
# 1468   49          1  Travel_Frequently       1023                   Sales
# 1469   34          1      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
ibm2['EducationField'].hist(grid=False)
# Out:
# <AxesSubplot:>

# %%
sb.catplot(x="EducationField", y="Attrition", data=ibm_iso, kind="bar", height=8)

# %% [markdown]
# Visualisation d’une distribution

# %%
sb.displot(ibm['MonthlyIncome'], kde = True)

# %%
sb.displot(ibm[ibm['MonthlyIncome'] < 5000]['MonthlyIncome'])

# %%
ibm[ibm['MonthlyIncome'] < 1400].describe()
# Out:
#              Age  Attrition    DailyRate  DistanceFromHome  Education  \
# count  16.000000  16.000000    16.000000         16.000000  16.000000
# mean   26.312500   0.500000   755.187500          8.312500   2.437500
# std     5.677074   0.516398   381.252536          7.364046   1.030776
# min    18.000000   0.000000   202.000000          1.000000   1.000000
# 25%    20.750000   0.000000   386.500000          2.000000   1.750000
# 50%    28.500000   0.500000   736.500000          7.500000   3.000000
# 75%    31.000000   1.000000  1028.500000         10.000000   3.000000
# max    35.000000   1.000000  1362.000000         24.000000   4.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# count           16.0       16.000000                16.000000   16.000000
# mean             1.0     1157.000000                 3.000000   61.750000
# std              0.0      602.907069                 0.966092   20.702657
# ...

# %% [markdown]
# Visualisation d’une relation linéaire

# %%
sb.lmplot(x="DistanceFromHome", y="EmployeeNumber", data=ibm[ibm['Attrition'] == 0])

# %%
ibm['Attrition'] = ibm['Attrition'].astype(int); ibm['Attrition']
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 1465    1
# 1466    1
# 1467    1
# 1468    1
# 1469    1
# Name: Attrition, Length: 1470, dtype: int32

# %%
sb.lmplot(x="DistanceFromHome", y="Attrition", data=ibm)

# %%
sb.displot(ibm[ibm['Attrition'] == 0]['DistanceFromHome'], kde = True)

# %% [markdown]
# Visualisation d’une heatmap

# %%
pricing = pd.read_csv('./files/house_pricing.csv')
house = pricing.iloc[:, -15:]; house
# Out:
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# ...

# %%
corr = house.corr(); corr
# Out:
#                WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# WoodDeckSF       1.000000     0.058661      -0.125989  -0.032771    -0.074181
# OpenPorchSF      0.058661     1.000000      -0.093079  -0.005842     0.074304
# EnclosedPorch   -0.125989    -0.093079       1.000000  -0.037305    -0.082864
# 3SsnPorch       -0.032771    -0.005842      -0.037305   1.000000    -0.031436
# ScreenPorch     -0.074181     0.074304      -0.082864  -0.031436     1.000000
# PoolArea         0.073378     0.060762       0.054203  -0.007992     0.051307
# MiscVal         -0.009551    -0.018584       0.018361   0.000354     0.031946
# MoSold           0.021011     0.071255      -0.028887   0.029474     0.023217
# YrSold           0.022270    -0.057619      -0.009916   0.018645     0.010694
# SalePrice        0.324413     0.315856      -0.128578   0.044584     0.111447
#
#                PoolArea   MiscVal    MoSold    YrSold  SalePrice
# ...

# %%
sb.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
f, ax = plt.subplots(figsize=(20,5))
sb.heatmap(corr, annot=True, ax =ax)
# Out:
# <AxesSubplot:>

# %%
house_2 = pricing.iloc[:, [3,4,80]]; house_2
# Out:
#       LotFrontage  LotArea  SalePrice
# 0            65.0     8450     208500
# 1            80.0     9600     181500
# 2            68.0    11250     223500
# 3            60.0     9550     140000
# 4            84.0    14260     250000
# ...           ...      ...        ...
# 1455         62.0     7917     175000
# 1456         85.0    13175     210000
# 1457         66.0     9042     266500
# 1458         68.0     9717     142125
# 1459         75.0     9937     147500
#
# [1460 rows x 3 columns]

# %%
corr_2 = house_2.corr(); corr_2
# Out:
#              LotFrontage   LotArea  SalePrice
# LotFrontage     1.000000  0.426095   0.351799
# LotArea         0.426095  1.000000   0.263843
# SalePrice       0.351799  0.263843   1.000000

# %%
f, ax = plt.subplots(figsize=(20,5))
sb.heatmap(corr_2, annot=True, ax =ax)
# Out:
# <AxesSubplot:>
